# %% [markdown]
# # Get RXNO *Reaction Types* Tree via Ontology Look Service (OLS) API
#
# * RXNO in TIB OLS (soon NFDI4Chem OLS) https://service.tib.eu/ts4tib/ontologies/rxno
# * RXNO in TIB OLS API https://service.tib.eu/ts4tib/api/ontologies/rxno
# * OLS API documentation https://www.ebi.ac.uk/ols/docs/api
#
# So that Chemotion *Reaction* menus can be populated with updated versions of RXNO-Reaction\ Types.ipynb
#
# ![](imgs/Chemtion_reactions.png)

# %%
import requests
from pprint import pprint


tib_ols_api = 'https://service.tib.eu/ts4tib/api/'
ols_rxno_rootterms = tib_ols_api + 'ontologies/rxno/terms/roots'

def terms_hierarchy(api_url, level):
    # calls OLS API on ontology terms 
    # prints the terms of a given level 
    # and requests the terms children, recursively 
    apirequest = requests.get(api_url)
    apiresponse = apirequest.json() 
    if '_embedded' in apiresponse.keys():
        terms = apiresponse['_embedded']['terms']
        for term in terms:
            if term['label'] != 'CHEBI_33855':
                ols_term_url = term['_links']['self']['href']
                # print(ols_term_url)
                print(f"{' ' * level * 2}{term['label']}")
                if 'children' in term['_links'].keys():
                    api_children_url = term['_links']['children']['href']
                    terms_hierarchy(api_url=term['_links']['children']['href'], level=level+1)
                    

terms_hierarchy(api_url=ols_rxno_rootterms, level=0)  # start from RXNO root classes
# Out:
#   Schmidt rearrangement, alkene
#           Schmidt rearrangement, tertiary alcohol
#           Baeyer-Villiger oxidation
#           Arndt-Eistert reaction
#         Mannich reaction
#         Stille coupling
#         Claisen condensation
#         Prins reaction
#         Knoevenagel condensation
#       ring formation reaction step
#         intramolecular Heck reaction
#         Johnson-Corey-Chaykovsky reaction
#           Johnson-Corey-Chaykovsky cyclopropane synthesis
#         ring expansion
#           Ciamician-Dennstedt rearrangement
#           Pfitzinger reaction
#           Auwers synthesis
#           Beirut reaction
#         heterocycle synthesis
#           thiacycle synthesis
#             Hinsberg thiophene synthesis
#             Gewald reaction
#             Paal-Knorr thiophene synthesis
#             Johnson-Corey-Chaykovsky thiirane synthesis
#           azacycle synthesis
#             Wenker synthesis
#             Pomeranz–Fritsch reaction
#             Niementowski quinazoline synthesis
#             cyclic Beckmann rearrangement
#             indole synthesis
#               Mori-Ban indole synthesis
#               Sandmeyer isonitrosoacetanilide isatin synthesis
#               Sandmeyer diphenylurea isatin synthesis
#               Larock indole synthesis
#               Bischler-Möhlau indole synthesis
#               Smith indole synthesis
#               Madelung indole synthesis
#               Cadogan indole synthesis
#               Bartoli indole synthesis
#               Fischer indole synthesis
#               Baeyer–Emmerling indole synthesis
#             quinoline synthesis
#               Doebner reaction
#               Niementowski quinoline synthesis
#               Friedlander quinoline synthesis
#               Knorr quinoline synthesis
#               Camps quinoline synthesis
#               Skraup reaction
#               Combes quinoline synthesis
#             pyrazole synthesis
#               Pechmann pyrazole synthesis
#               Knorr pyrazole synthesis
#             pyridine synthesis
#               Chichibabin pyridine synthesis
#               Kröhnke pyridine synthesis
#               Hantzsch pyridine synthesis
#             carbazole synthesis
#               Borsche-Drechsel cyclisation
#               Cadogan carbazole synthesis
#             acridine synthesis
#               Bernthsen acridine synthesis
#             pyrrole synthesis
#               Clauson-Kaas reaction
#               Paal-Knorr pyrrole synthesis
#               Barton-Zard reaction
#             Johnson-Corey-Chaykovsky aziridine synthesis
#             triazine synthesis
#               Pinner triazine synthesis
#             pyrimidine synthesis
#               Pinner pyrimidine synthesis
#             piperidine synthesis
#               Hofmann-Löffler-Freytag piperidine synthesis
#             piperazine synthesis
#             indazole synthesis
#             imidazole synthesis
#             Hofmann-Löffler-Freytag reaction
#             pyrrolidine synthesis
#               Hofmann-Löffler-Freytag pyrrolidine synthesis
#           oxacycle synthesis
#             Yamaguchi lactonisation
#             Johnson-Corey-Chaykovsky epoxide synthesis
#             halolactonization
#               iodolactonization
#               chlorolactonization
#               bromolactonization
#             Paal-Knorr furan synthesis
#             Sharpless asymmetric epoxidation
#             Feist-Bénary synthesis
#             Allan-Robinson reaction
#               Allan-Robinson isoflavone synthesis
#               Allan-Robinson flavone synthesis
#             Auwers synthesis
#             Algar-Flynn-Oyamada reaction
#             Paternò–Büchi reaction
#             Prilezhaev epoxidation
#             oxa-Pictet-Spengler reaction
#         Paal-Knorr synthesis
#           Paal-Knorr pyrrole synthesis
#           Paal-Knorr thiophene synthesis
#           Paal-Knorr furan synthesis
#         intramolecular Scholl reaction
#         Nazarov cyclisation
#         ring contraction
#           Wallach degradation
#           cyclic alpha-haloketone Favorskii rearrangement
#         ring rearrangement
#           Clauson-Kaas reaction
#           aza-Payne rearrangement
#           Payne rearrangement
#           Boulton-Katritzky rearrangement
#             bicyclic Boulton-Katritzky rearrangement
#             monocyclic Boulton-Katritzky rearrangement
#           aza-Achmatowicz rearrangement
#           Achmatowicz rearrangement
#           Dimroth rearrangement
#         ring-closing metathesis
#         Bergman cyclisation
#         Schmittel cyclisation
#         Myers-Saito cyclisation
#         Biginelli reaction
#         intramolecular acyloin condensation
#         intramolecular Prins reaction
#         ring-closing enyne metathesis
#         Simmons-Smith reaction
#         interrupted Nazarov cyclisation
#         Dieckmann cyclisation
#       rearrangement step
#         Baker-Venkataraman rearrangement
#         Brook rearrangement
#         Lossen rearrangement
#         Favorskii rearrangement
#           cyclic alpha-haloketone Favorskii rearrangement
#         Ireland-Claisen rearrangement
#         Claisen rearrangement
#         Demjanov rearrangement
#         Tiffeneau-Demjanov rearrangement
#         aza-Cope rearrangement
#           3-aza-Cope rearrangement
#           2-aza-Cope rearrangement
#           1-aza-Cope rearrangement
#         Stevens rearrangement
#           Stevens rearrangement, sulfonium
#           Stevens rearrangement, ammonium
#         Neber rearrangement
#         Sommelet-Hauser rearrangement
#         Fischer-Hepp rearrangement
#         Chapman rearrangement
#         Mumm rearrangement
#         aromatic Claisen rearrangement
#         Steglich rearrangement
#         Fries rearrangement
#           para-Fries rearrangement
#           ortho-Fries rearrangement
#         Carroll rearrangement
#         metalla-aza-Claisen rearrangement
#       functional modification
#         molecular skeleton elimination reaction
#           Saegusa oxidation
#           Eastwood reaction
#           Cope elimination
#           Chugaev reaction
#           Bamford-Stevens reaction
#           Shapiro reaction
#           Hofmann elimination
#         substitution step
#           Yamaguchi esterification
#             Yamaguchi lactonisation
#           Nicholas reaction
#             Nicholas reaction, nucleophilic carbon centre
#             Nicholas reaction, nucleophilic heteroatom centre
#           Ing-Manske procedure
#           Gabriel synthesis
#           aromatic substitution step
#             Balz-Schiemann reaction
#             Buchwald-Hartwig amination
#             Boyland-Sims oxidation
#             Elbs persulfate oxidation, phenol variant
#             Zincke nitration
#             Koerner-Contardi reaction
#             Gattermann halogenation
#               Gattermann chlorination
#               Gattermann bromination
#             Sandmeyer reaction
#               Sandmeyer halogenation
#                 Sandmeyer fluorination
#                 Sandmeyer iodination
#                 Sandmeyer bromination
#                 Sandmeyer chlorination
#               Sandmeyer pseudohalogenation
#             Bart reaction
#             Goldberg reaction
#             Ullmann condensation
#           Fischer-Speier esterification
#           Schotten-Baumann reaction
#           Demjanov rearrangement
#           Kharasch-Sosnovsky reaction
#           Chichibabin reaction
#           Katritzky pyrylium-pyridinium method
#           Tamao oxidation
#           Fleming-Tamao oxidation
#           Mitsunobu reaction
#             Bose-Mitsunobu reaction
#           Williamson ether synthesis
#           Arbuzov reaction
#         functional group addition step
#           Sugasawa reaction
#           Quelet reaction
#           Bohn-Schmidt reaction
#           Baudisch reaction
#           Wohl-Ziegler bromination
#         deprotection reaction
#           amino group deprotection
#             benzylamine deprotection
#             Boc deprotection
#             phthalimide deprotection
#           hydroxy group deprotection
#             pivaloyl deprotection
#           carboxy group deprotection
#             ethyl ester deprotection
#             methyl ester deprotection
#             tert-butyl ester deprotection
#         addition reaction step
#           Sharpless asymmetric aminohydroxylation
#           Sharpless asymmetric dihydroxylation
#           Benkeser reduction
#           Noyori asymmetric hydrogenation, alkene
#           Birch reduction
#           Stork-Crabtree hydrogenation
#           hydroboration
#           hydroamination
#           hydrosilylation
#             photohydrosilylation
#             thermal hydrosilylation
#           hydrometallation
#             hydroalumination
#             hydrotelluration
#             hydrostannylation
#             hydrozirconation
#           hydroboration-oxidation
#         functional group modification
#           reductive imination
#           nitrile to acid conversion
#           carboxylic acid to acid chloride conversion
#           alcohol to halide conversion
#             Appel halogenation
#               Appel iodination
#               Appel bromination
#                 Appel bromination with bromine
#                 Appel bromination with tetrabromomethane
#               Appel chlorination
#           amide to imidoyl chloride conversion
#           carbonyl compound to imine conversion
#             aza-Wittig reaction
#           Pinner reaction
#           Sommelet reaction
#           amide reduction to amine
#           nitro reduction to amine
#           reductive amination
#             Leuckart-Wallach reaction
#             Leuckart reaction
#               Leuckart ketone reaction
#               Leuckart aldehyde reaction
#           Nef reaction
#           Finkelstein reaction
#             sulfonate ester Finkelstein reaction
#             bromide Finkelstein reaction
#             chloride Finkelstein reaction
#           Demko-Sharpless reaction
#           Tishchenko reaction
#           Willgerodt-Kindler reaction
#           Willgerodt reaction
#           azo coupling
#           Bodroux reaction
#           Mukaiyama-Hoshino method
#         protection reaction
#           amino group protection
#             benzylamine protection
#             Fmoc protection
#             phthalimide protection
#             Boc protection
#           carboxylic acid protection
#             tert-butyl protection
#           hydroxyl group protection
#             silyl protection
#             benzyl ether protection
#             acetate protection
#             pivaloyl protection
#       cleaving reaction
#         fragmentation reaction
#           Grob fragmentation
#         end-of-chain chain shortening
#           Hunsdiecker reaction
#           Weerman reaction
#           Barbier-Wieland degradation
#           Barton decarboxylation
#           Schmidt rearrangement, carboxylic acid
#           Krapcho decarboxylation
#           Hofmann rearrangement
#           Hofmann reaction
#           Strecker degradation
#         Dakin reaction
#         Japp-Klingemann reaction
#         Emde degradation
#         Beckmann fragmentation
#         extrusion reaction
#           Ramberg-Bäcklund reaction
#           semidine rearrangement
#           benzidine rearrangement
#         terminal amino-acid residue cleaving reaction
#           Bergmann degradation
#           Edman degradation
#         Malaprade reaction
#         Polonovski reaction
#           Polonovski-Potier reaction
#         retro-aldol addition
#         Criegee oxidation
#         Lemieux-Johnson oxidation
#   molecular process
#     solvolysis
#       hydrolysis
#     heterocycle synthesis
#       thiacycle synthesis
#         Hinsberg thiophene synthesis
#         Gewald reaction
#         Paal-Knorr thiophene synthesis
#         Johnson-Corey-Chaykovsky thiirane synthesis
#       azacycle synthesis
#         Wenker synthesis
#         Pomeranz–Fritsch reaction
#         Niementowski quinazoline synthesis
#         cyclic Beckmann rearrangement
#         indole synthesis
#           Mori-Ban indole synthesis
#           Sandmeyer isonitrosoacetanilide isatin synthesis
#           Sandmeyer diphenylurea isatin synthesis
#           Larock indole synthesis
#           Bischler-Möhlau indole synthesis
#           Smith indole synthesis
#           Madelung indole synthesis
#           Cadogan indole synthesis
#           Bartoli indole synthesis
#           Fischer indole synthesis
#           Baeyer–Emmerling indole synthesis
#         quinoline synthesis
#           Doebner reaction
#           Niementowski quinoline synthesis
#           Friedlander quinoline synthesis
#           Knorr quinoline synthesis
#           Camps quinoline synthesis
#           Skraup reaction
#           Combes quinoline synthesis
#         pyrazole synthesis
#           Pechmann pyrazole synthesis
#           Knorr pyrazole synthesis
#         pyridine synthesis
#           Chichibabin pyridine synthesis
#           Kröhnke pyridine synthesis
#           Hantzsch pyridine synthesis
#         carbazole synthesis
#           Borsche-Drechsel cyclisation
#           Cadogan carbazole synthesis
#         acridine synthesis
#           Bernthsen acridine synthesis
#         pyrrole synthesis
#           Clauson-Kaas reaction
#           Paal-Knorr pyrrole synthesis
#           Barton-Zard reaction
#         Johnson-Corey-Chaykovsky aziridine synthesis
#         triazine synthesis
#           Pinner triazine synthesis
#         pyrimidine synthesis
#           Pinner pyrimidine synthesis
#         piperidine synthesis
#           Hofmann-Löffler-Freytag piperidine synthesis
#         piperazine synthesis
#         indazole synthesis
#         imidazole synthesis
#         Hofmann-Löffler-Freytag reaction
#         pyrrolidine synthesis
#           Hofmann-Löffler-Freytag pyrrolidine synthesis
#       oxacycle synthesis
#         Yamaguchi lactonisation
#         Johnson-Corey-Chaykovsky epoxide synthesis
#         halolactonization
#           iodolactonization
#           chlorolactonization
#           bromolactonization
#         Paal-Knorr furan synthesis
#         Sharpless asymmetric epoxidation
#         Feist-Bénary synthesis
#         Allan-Robinson reaction
#           Allan-Robinson isoflavone synthesis
#           Allan-Robinson flavone synthesis
#         Auwers synthesis
#         Algar-Flynn-Oyamada reaction
#         Paternò–Büchi reaction
#         Prilezhaev epoxidation
#         oxa-Pictet-Spengler reaction
#     thiacycle synthesis
#       Hinsberg thiophene synthesis
#       Gewald reaction
#       Paal-Knorr thiophene synthesis
#       Johnson-Corey-Chaykovsky thiirane synthesis
#     azacycle synthesis
#       Wenker synthesis
#       Pomeranz–Fritsch reaction
#       Niementowski quinazoline synthesis
#       cyclic Beckmann rearrangement
#       indole synthesis
#         Mori-Ban indole synthesis
#         Sandmeyer isonitrosoacetanilide isatin synthesis
#         Sandmeyer diphenylurea isatin synthesis
#         Larock indole synthesis
#         Bischler-Möhlau indole synthesis
#         Smith indole synthesis
#         Madelung indole synthesis
#         Cadogan indole synthesis
#         Bartoli indole synthesis
#         Fischer indole synthesis
#         Baeyer–Emmerling indole synthesis
#       quinoline synthesis
#         Doebner reaction
#         Niementowski quinoline synthesis
#         Friedlander quinoline synthesis
#         Knorr quinoline synthesis
#         Camps quinoline synthesis
#         Skraup reaction
#         Combes quinoline synthesis
#       pyrazole synthesis
#         Pechmann pyrazole synthesis
#         Knorr pyrazole synthesis
#       pyridine synthesis
#         Chichibabin pyridine synthesis
#         Kröhnke pyridine synthesis
#         Hantzsch pyridine synthesis
#       carbazole synthesis
#         Borsche-Drechsel cyclisation
#         Cadogan carbazole synthesis
#       acridine synthesis
#         Bernthsen acridine synthesis
#       pyrrole synthesis
#         Clauson-Kaas reaction
#         Paal-Knorr pyrrole synthesis
#         Barton-Zard reaction
#       Johnson-Corey-Chaykovsky aziridine synthesis
#       triazine synthesis
#         Pinner triazine synthesis
#       pyrimidine synthesis
#         Pinner pyrimidine synthesis
#       piperidine synthesis
#         Hofmann-Löffler-Freytag piperidine synthesis
#       piperazine synthesis
#       indazole synthesis
#       imidazole synthesis
#       Hofmann-Löffler-Freytag reaction
#       pyrrolidine synthesis
#         Hofmann-Löffler-Freytag pyrrolidine synthesis
#     oxacycle synthesis
#       Yamaguchi lactonisation
#       Johnson-Corey-Chaykovsky epoxide synthesis
#       halolactonization
#         iodolactonization
#         chlorolactonization
#         bromolactonization
#       Paal-Knorr furan synthesis
#       Sharpless asymmetric epoxidation
#       Feist-Bénary synthesis
#       Allan-Robinson reaction
#         Allan-Robinson isoflavone synthesis
#         Allan-Robinson flavone synthesis
#       Auwers synthesis
#       Algar-Flynn-Oyamada reaction
#       Paternò–Büchi reaction
#       Prilezhaev epoxidation
#       oxa-Pictet-Spengler reaction
#     indole synthesis
#       Mori-Ban indole synthesis
#       Sandmeyer isonitrosoacetanilide isatin synthesis
#       Sandmeyer diphenylurea isatin synthesis
#       Larock indole synthesis
#       Bischler-Möhlau indole synthesis
#       Smith indole synthesis
#       Madelung indole synthesis
#       Cadogan indole synthesis
#       Bartoli indole synthesis
#       Fischer indole synthesis
#       Baeyer–Emmerling indole synthesis
#     quinoline synthesis
#       Doebner reaction
#       Niementowski quinoline synthesis
#       Friedlander quinoline synthesis
#       Knorr quinoline synthesis
#       Camps quinoline synthesis
#       Skraup reaction
#       Combes quinoline synthesis
#     condensation reaction
#       ester condensation reaction
#       dealcoholative condensation
#         deethanolative condensation
#           Claisen condensation
#           Dieckmann cyclisation
#         Conrad-Limpach cyclisation
#       molecular dehydration reaction
#         Ugi reaction
#         Claisen-Schmidt condensation
#         Wenker synthesis
#         Knorr pyrazole synthesis
#         Madelung indole synthesis
#         Biginelli reaction
#         aldol condensation
#           Perkin reaction
#           Mukaiyama aldol condensation
#         Skraup reaction
#         Combes quinoline synthesis
#       decarboxylative condensation
#         Knoevenagel condensation
#         Darzens reaction
#           haloethanoate ester-ketone Darzens reaction
#           haloethanoate ester-aldehyde Darzens reaction
#       Pictet-Spengler reaction
#       oxa-Pictet-Spengler reaction
#     elimination reaction
#     pyridine synthesis
#       Chichibabin pyridine synthesis
#       Kröhnke pyridine synthesis
#       Hantzsch pyridine synthesis
#     carbazole synthesis
#       Borsche-Drechsel cyclisation
#       Cadogan carbazole synthesis
#     acridine synthesis
#       Bernthsen acridine synthesis
#     enolisation
#     accepting an electron pair in Lewis adduct formation
#     hydron donation
#     base catalysis
#       Brønsted base catalysis
#       Lewis base catalysis
#     Lewis adduct formation
#     electron pair donation in Lewis adduct formation
#     accepting a hydron
#     [3,3]-sigmatropic rearrangement
#       Johnson-Claisen rearrangement
#       Eschenmoser-Claisen rearrangement
#       Bellus-Claisen rearrangement
#       Ireland-Claisen rearrangement
#       Claisen rearrangement
#       aza-Cope rearrangement
#         3-aza-Cope rearrangement
#         2-aza-Cope rearrangement
#         1-aza-Cope rearrangement
#       aromatic Claisen rearrangement
#       oxy-Cope rearrangement
#       Cope rearrangement
# chemical entity
#   atom
#     metal atom
#       transition element atom
#         nickel atom
#         zinc atom
#         copper atom
#         titanium atom
#         palladium atom
#         platinum atom
#       sodium atom
#     phosphorus atom
#   group
#     amino groups
#       amino group
#     formyl group
#     nitro group
#     pseudohalo group
#     aryl group
#     carboxy group
#     hydroxy group
#   molecular entity
#     hydrogen chloride
#     hydrogen bromide
#     chalcones
#     alkene
#     phosphonium ylide
#     dibromine
#     nitrile
#     nitro compound
#     nitrate ester
#     carboximides
#       formamides
#     organooxygen compound
#       ether
#     enyne
#     tetrabromomethane
#     chromium coordination entity
#       chromium trioxide
#     tertiary phosphine
#     allenes
#     arylacetylene
#     phosphine oxide
#     cinnamic acids
#     sodium azide
# Bingel reaction

# %% [markdown]
# # API Response
# ##  Class: Baeyer–Emmerling indole synthesis (RXNO_0000632)
# * [OLS API term](https://service.tib.eu/ts4tib/api/ontologies/rxno/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FRXNO_0000632)
# * [OLS Web-UI term](https://service.tib.eu/ts4tib/ontologies/rxno/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FRXNO_0000632)
#
# ```json
# {
#   "iri" : "http://purl.obolibrary.org/obo/RXNO_0000632",
#   "label" : "Baeyer–Emmerling indole synthesis",
#   "description" : [ "An indole synthesis where an ortho-nitrocinnamic acid reacts with iron powder in a basic solution to form an indole." ],
#   "annotation" : {
#     "database_cross_reference" : [ "https://www.wikidata.org/wiki/Q3159940", "NAMERXN:4.1.41", "https://doi.org/10.1002/cber.186900201268" ],
#     "has_obo_namespace" : [ "RXNO" ],
#     "id" : [ "RXNO:0000632" ]
#   },
#   "synonyms" : null,
#   "ontology_name" : "rxno",
#   "ontology_prefix" : "RXNO",
#   "ontology_iri" : "http://purl.obolibrary.org/obo/rxno.obo.owl",
#   "is_obsolete" : false,
#   "term_replaced_by" : null,
#   "is_defining_ontology" : true,
#   "has_children" : false,
#   "is_root" : false,
#   "short_form" : "RXNO_0000632",
#   "obo_id" : "RXNO:0000632",
#   "in_subset" : null,
#   "obo_definition_citation" : [
#       {"definition":"An indole synthesis where an ortho-nitrocinnamic acid reacts with iron powder in a basic solution to form an indole.","oboXrefs":[{"database":null,"id":"https://orcid.org/0000-0001-5985-7429","description":null,"url":"https://orcid.org/0000-0001-5985-7429"}]}],
#   "obo_xref" : [
#       {"database":"NAMERXN","id":"4.1.41","description":null,"url":null},
#       {"database":null,"id":"https://doi.org/10.1002/cber.186900201268","description":null,"url":"https://doi.org/10.1002/cber.186900201268"},
#       {"database":null,"id":"https://www.wikidata.org/wiki/Q3159940","description":null,"url":"https://www.wikidata.org/wiki/Q3159940"}],
#   "obo_synonym" : null,
#   "is_preferred_root" : false,
#   "_links" : {
#     "self" : {
#       "href" : "https://service.tib.eu/ts4tib/api/ontologies/rxno/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FRXNO_0000632"
#     },
#     "parents" : {
#       "href" : "https://service.tib.eu/ts4tib/api/ontologies/rxno/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FRXNO_0000632/parents"
#     },
#     "ancestors" : {
#       "href" : "https://service.tib.eu/ts4tib/api/ontologies/rxno/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FRXNO_0000632/ancestors"
#     },
#     "hierarchicalParents" : {
#       "href" : "https://service.tib.eu/ts4tib/api/ontologies/rxno/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FRXNO_0000632/hierarchicalParents"
#     },
#     "hierarchicalAncestors" : {
#       "href" : "https://service.tib.eu/ts4tib/api/ontologies/rxno/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FRXNO_0000632/hierarchicalAncestors"
#     },
#     "jstree" : {
#       "href" : "https://service.tib.eu/ts4tib/api/ontologies/rxno/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FRXNO_0000632/jstree"
#     },
#     "graph" : {
#       "href" : "https://service.tib.eu/ts4tib/api/ontologies/rxno/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FRXNO_0000632/graph"
#     }
#   }
# }
# ```

# %%
# 'obo_xref' - Wikidata
# same previous example, but with displaying Wikidata reaction item present in OLS 'obo_xref' key 

import requests
from pprint import pprint


tib_ols_api = 'https://service.tib.eu/ts4tib/api/'
ols_rxno_rootterms = tib_ols_api + 'ontologies/rxno/terms/roots'

def get_wikidata_obo_xref(olsterm):
    # returns the wikidata 'obo_xref' from a ontology term 
    if 'obo_xref' in olsterm.keys() and olsterm['obo_xref'] and len(olsterm['obo_xref']) > 0:
        wikidata_url = [ ref['url'] for ref in olsterm['obo_xref'] if ref['url'] and 'wikidata' in ref['url']]
        if len(wikidata_url) > 0:
            wikidata_url = wikidata_url[0]
            return wikidata_url
        else:
            return None


def terms_hierarchy(api_url, level):
    # calls OLS API on ontology terms 
    # prints the terms of a given level 
    # and requests the terms children, recursively 
    apirequest = requests.get(api_url)
    apiresponse = apirequest.json() 
    if '_embedded' in apiresponse.keys():
        terms = apiresponse['_embedded']['terms']
        for term in terms:
            if term['label'] != 'CHEBI_33855':
                ols_term_url = term['_links']['self']['href']
                wikidata_item = get_wikidata_obo_xref(olsterm=term)  # <---- 
                print(f"{' ' * level * 2}{term['label']} {wikidata_item if wikidata_item else ''}")
                if 'children' in term['_links'].keys():
                    api_children_url = term['_links']['children']['href']
                    terms_hierarchy(api_url=term['_links']['children']['href'], level=level+1)
                    

terms_hierarchy(api_url=ols_rxno_rootterms, level=0)  # start from RXNO root classes
# Out:
# //www.wikidata.org/wiki/Q900370
#           Chugaev reaction
#           Bamford-Stevens reaction    https://www.wikidata.org/wiki/Q575939
#           Shapiro reaction    https://www.wikidata.org/wiki/Q846597
#           Hofmann elimination
#         substitution step
#           Yamaguchi esterification
#             Yamaguchi lactonisation
#           Nicholas reaction    https://www.wikidata.org/wiki/Q902932
#             Nicholas reaction, nucleophilic carbon centre
#             Nicholas reaction, nucleophilic heteroatom centre
#           Ing-Manske procedure
#           Gabriel synthesis    https://www.wikidata.org/wiki/Q123422
#           aromatic substitution step
#             Balz-Schiemann reaction    https://www.wikidata.org/wiki/Q572113
#             Buchwald-Hartwig amination
#             Boyland-Sims oxidation
#             Elbs persulfate oxidation, phenol variant
#             Zincke nitration    https://www.wikidata.org/wiki/Q1061336
#             Koerner-Contardi reaction
#             Gattermann halogenation
#               Gattermann chlorination
#               Gattermann bromination
#             Sandmeyer reaction    https://www.wikidata.org/wiki/Q898821
#               Sandmeyer halogenation
#                 Sandmeyer fluorination
#                 Sandmeyer iodination
#                 Sandmeyer bromination
#                 Sandmeyer chlorination
#               Sandmeyer pseudohalogenation
#             Bart reaction
#             Goldberg reaction
#             Ullmann condensation    https://www.wikidata.org/wiki/Q2371705
#           Fischer-Speier esterification
#           Schotten-Baumann reaction
#           Demjanov rearrangement
#           Kharasch-Sosnovsky reaction
#           Chichibabin reaction
#           Katritzky pyrylium-pyridinium method
#           Tamao oxidation
#           Fleming-Tamao oxidation
#           Mitsunobu reaction    https://www.wikidata.org/wiki/Q899062
#             Bose-Mitsunobu reaction
#           Williamson ether synthesis    https://www.wikidata.org/wiki/Q898790
#           Arbuzov reaction    https://www.wikidata.org/wiki/Q630801
#         functional group addition step
#           Sugasawa reaction
#           Quelet reaction
#           Bohn-Schmidt reaction
#           Baudisch reaction    https://www.wikidata.org/wiki/Q3536586
#           Wohl-Ziegler bromination
#         deprotection reaction
#           amino group deprotection
#             benzylamine deprotection
#             Boc deprotection
#             phthalimide deprotection
#           hydroxy group deprotection
#             pivaloyl deprotection
#           carboxy group deprotection
#             ethyl ester deprotection
#             methyl ester deprotection
#             tert-butyl ester deprotection
#         addition reaction step
#           Sharpless asymmetric aminohydroxylation
#           Sharpless asymmetric dihydroxylation    https://www.wikidata.org/wiki/Q752651
#           Benkeser reduction
#           Noyori asymmetric hydrogenation, alkene
#           Birch reduction    https://www.wikidata.org/wiki/Q864996
#           Stork-Crabtree hydrogenation
#           hydroboration
#           hydroamination
#           hydrosilylation
#             photohydrosilylation
#             thermal hydrosilylation
#           hydrometallation
#             hydroalumination
#             hydrotelluration
#             hydrostannylation
#             hydrozirconation
#           hydroboration-oxidation
#         functional group modification
#           reductive imination
#           nitrile to acid conversion
#           carboxylic acid to acid chloride conversion
#           alcohol to halide conversion
#             Appel halogenation
#               Appel iodination
#               Appel bromination
#                 Appel bromination with bromine
#                 Appel bromination with tetrabromomethane
#               Appel chlorination
#           amide to imidoyl chloride conversion
#           carbonyl compound to imine conversion
#             aza-Wittig reaction
#           Pinner reaction
#           Sommelet reaction    https://www.wikidata.org/wiki/Q909040
#           amide reduction to amine
#           nitro reduction to amine
#           reductive amination
#             Leuckart-Wallach reaction    https://www.wikidata.org/wiki/Q726513
#             Leuckart reaction    https://www.wikidata.org/wiki/Q726513
#               Leuckart ketone reaction
#               Leuckart aldehyde reaction
#           Nef reaction
#           Finkelstein reaction
#             sulfonate ester Finkelstein reaction
#             bromide Finkelstein reaction
#             chloride Finkelstein reaction
#           Demko-Sharpless reaction
#           Tishchenko reaction
#           Willgerodt-Kindler reaction
#           Willgerodt reaction
#           azo coupling    https://www.wikidata.org/wiki/Q668665
#           Bodroux reaction
#           Mukaiyama-Hoshino method
#         protection reaction
#           amino group protection
#             benzylamine protection
#             Fmoc protection
#             phthalimide protection
#             Boc protection
#           carboxylic acid protection
#             tert-butyl protection
#           hydroxyl group protection
#             silyl protection
#             benzyl ether protection
#             acetate protection
#             pivaloyl protection
#       cleaving reaction
#         fragmentation reaction
#           Grob fragmentation    https://www.wikidata.org/wiki/Q5609896
#         end-of-chain chain shortening
#           Hunsdiecker reaction    https://www.wikidata.org/wiki/Q902216
#           Weerman reaction
#           Barbier-Wieland degradation    https://www.wikidata.org/wiki/Q5801440
#           Barton decarboxylation    https://www.wikidata.org/wiki/Q3454335
#           Schmidt rearrangement, carboxylic acid
#           Krapcho decarboxylation    https://www.wikidata.org/wiki/Q4597398
#           Hofmann rearrangement
#           Hofmann reaction
#           Strecker degradation
#         Dakin reaction
#         Japp-Klingemann reaction
#         Emde degradation    https://www.wikidata.org/wiki/Q2026108
#         Beckmann fragmentation
#         extrusion reaction    https://www.wikidata.org/wiki/Q31287730
#           Ramberg-Bäcklund reaction    https://www.wikidata.org/wiki/Q1935557
#           semidine rearrangement
#           benzidine rearrangement    https://www.wikidata.org/wiki/Q465781
#         terminal amino-acid residue cleaving reaction
#           Bergmann degradation
#           Edman degradation    https://www.wikidata.org/wiki/Q898506
#         Malaprade reaction    https://www.wikidata.org/wiki/Q10851620
#         Polonovski reaction
#           Polonovski-Potier reaction
#         retro-aldol addition
#         Criegee oxidation    https://www.wikidata.org/wiki/Q30693026
#         Lemieux-Johnson oxidation    https://www.wikidata.org/wiki/Q6521154
#   molecular process
#     solvolysis
#       hydrolysis
#     heterocycle synthesis
#       thiacycle synthesis
#         Hinsberg thiophene synthesis    https://www.wikidata.org/wiki/Q18020904
#         Gewald reaction    https://www.wikidata.org/wiki/Q240091
#         Paal-Knorr thiophene synthesis
#         Johnson-Corey-Chaykovsky thiirane synthesis
#       azacycle synthesis
#         Wenker synthesis    https://www.wikidata.org/wiki/Q900233
#         Pomeranz–Fritsch reaction    https://www.wikidata.org/wiki/Q18217151
#         Niementowski quinazoline synthesis    https://www.wikidata.org/wiki/Q1059542
#         cyclic Beckmann rearrangement
#         indole synthesis
#           Mori-Ban indole synthesis
#           Sandmeyer isonitrosoacetanilide isatin synthesis
#           Sandmeyer diphenylurea isatin synthesis
#           Larock indole synthesis
#           Bischler-Möhlau indole synthesis
#           Smith indole synthesis
#           Madelung indole synthesis    https://www.wikidata.org/wiki/Q2632831
#           Cadogan indole synthesis
#           Bartoli indole synthesis    https://www.wikidata.org/wiki/Q3508929
#           Fischer indole synthesis    https://www.wikidata.org/wiki/Q901218
#           Baeyer–Emmerling indole synthesis    https://www.wikidata.org/wiki/Q3159940
#         quinoline synthesis
#           Doebner reaction    https://www.wikidata.org/wiki/Q3772250
#           Niementowski quinoline synthesis    https://www.wikidata.org/wiki/Q2733837
#           Friedlander quinoline synthesis    https://www.wikidata.org/wiki/Q1058388
#           Knorr quinoline synthesis
#           Camps quinoline synthesis
#           Skraup reaction    https://www.wikidata.org/wiki/Q903836
#           Combes quinoline synthesis    https://www.wikidata.org/wiki/Q1058068
#         pyrazole synthesis
#           Pechmann pyrazole synthesis
#           Knorr pyrazole synthesis
#         pyridine synthesis
#           Chichibabin pyridine synthesis
#           Kröhnke pyridine synthesis    https://www.wikidata.org/wiki/Q2144364
#           Hantzsch pyridine synthesis
#         carbazole synthesis
#           Borsche-Drechsel cyclisation
#           Cadogan carbazole synthesis
#         acridine synthesis
#           Bernthsen acridine synthesis
#         pyrrole synthesis
#           Clauson-Kaas reaction
#           Paal-Knorr pyrrole synthesis
#           Barton-Zard reaction    https://www.wikidata.org/wiki/Q4865733
#         Johnson-Corey-Chaykovsky aziridine synthesis
#         triazine synthesis
#           Pinner triazine synthesis
#         pyrimidine synthesis
#           Pinner pyrimidine synthesis
#         piperidine synthesis
#           Hofmann-Löffler-Freytag piperidine synthesis
#         piperazine synthesis
#         indazole synthesis
#         imidazole synthesis
#         Hofmann-Löffler-Freytag reaction    https://www.wikidata.org/wiki/Q5876831
#         pyrrolidine synthesis
#           Hofmann-Löffler-Freytag pyrrolidine synthesis
#       oxacycle synthesis
#         Yamaguchi lactonisation
#         Johnson-Corey-Chaykovsky epoxide synthesis
#         halolactonization
#           iodolactonization    https://www.wikidata.org/wiki/Q6062283
#           chlorolactonization
#           bromolactonization
#         Paal-Knorr furan synthesis
#         Sharpless asymmetric epoxidation    https://www.wikidata.org/wiki/Q56672072
#         Feist-Bénary synthesis    https://www.wikidata.org/wiki/Q5441589
#         Allan-Robinson reaction    https://www.wikidata.org/wiki/Q3046015
#           Allan-Robinson isoflavone synthesis
#           Allan-Robinson flavone synthesis
#         Auwers synthesis    https://www.wikidata.org/wiki/Q3115850
#         Algar-Flynn-Oyamada reaction    https://www.wikidata.org/wiki/Q903717
#         Paternò–Büchi reaction    https://www.wikidata.org/wiki/Q902254
#         Prilezhaev epoxidation
#         oxa-Pictet-Spengler reaction
#     thiacycle synthesis
#       Hinsberg thiophene synthesis    https://www.wikidata.org/wiki/Q18020904
#       Gewald reaction    https://www.wikidata.org/wiki/Q240091
#       Paal-Knorr thiophene synthesis
#       Johnson-Corey-Chaykovsky thiirane synthesis
#     azacycle synthesis
#       Wenker synthesis    https://www.wikidata.org/wiki/Q900233
#       Pomeranz–Fritsch reaction    https://www.wikidata.org/wiki/Q18217151
#       Niementowski quinazoline synthesis    https://www.wikidata.org/wiki/Q1059542
#       cyclic Beckmann rearrangement
#       indole synthesis
#         Mori-Ban indole synthesis
#         Sandmeyer isonitrosoacetanilide isatin synthesis
#         Sandmeyer diphenylurea isatin synthesis
#         Larock indole synthesis
#         Bischler-Möhlau indole synthesis
#         Smith indole synthesis
#         Madelung indole synthesis    https://www.wikidata.org/wiki/Q2632831
#         Cadogan indole synthesis
#         Bartoli indole synthesis    https://www.wikidata.org/wiki/Q3508929
#         Fischer indole synthesis    https://www.wikidata.org/wiki/Q901218
#         Baeyer–Emmerling indole synthesis    https://www.wikidata.org/wiki/Q3159940
#       quinoline synthesis
#         Doebner reaction    https://www.wikidata.org/wiki/Q3772250
#         Niementowski quinoline synthesis    https://www.wikidata.org/wiki/Q2733837
#         Friedlander quinoline synthesis    https://www.wikidata.org/wiki/Q1058388
#         Knorr quinoline synthesis
#         Camps quinoline synthesis
#         Skraup reaction    https://www.wikidata.org/wiki/Q903836
#         Combes quinoline synthesis    https://www.wikidata.org/wiki/Q1058068
#       pyrazole synthesis
#         Pechmann pyrazole synthesis
#         Knorr pyrazole synthesis
#       pyridine synthesis
#         Chichibabin pyridine synthesis
#         Kröhnke pyridine synthesis    https://www.wikidata.org/wiki/Q2144364
#         Hantzsch pyridine synthesis
#       carbazole synthesis
#         Borsche-Drechsel cyclisation
#         Cadogan carbazole synthesis
#       acridine synthesis
#         Bernthsen acridine synthesis
#       pyrrole synthesis
#         Clauson-Kaas reaction
#         Paal-Knorr pyrrole synthesis
#         Barton-Zard reaction    https://www.wikidata.org/wiki/Q4865733
#       Johnson-Corey-Chaykovsky aziridine synthesis
#       triazine synthesis
#         Pinner triazine synthesis
#       pyrimidine synthesis
#         Pinner pyrimidine synthesis
#       piperidine synthesis
#         Hofmann-Löffler-Freytag piperidine synthesis
#       piperazine synthesis
#       indazole synthesis
#       imidazole synthesis
#       Hofmann-Löffler-Freytag reaction    https://www.wikidata.org/wiki/Q5876831
#       pyrrolidine synthesis
#         Hofmann-Löffler-Freytag pyrrolidine synthesis
#     oxacycle synthesis
#       Yamaguchi lactonisation
#       Johnson-Corey-Chaykovsky epoxide synthesis
#       halolactonization
#         iodolactonization    https://www.wikidata.org/wiki/Q6062283
#         chlorolactonization
#         bromolactonization
#       Paal-Knorr furan synthesis
#       Sharpless asymmetric epoxidation    https://www.wikidata.org/wiki/Q56672072
#       Feist-Bénary synthesis    https://www.wikidata.org/wiki/Q5441589
#       Allan-Robinson reaction    https://www.wikidata.org/wiki/Q3046015
#         Allan-Robinson isoflavone synthesis
#         Allan-Robinson flavone synthesis
#       Auwers synthesis    https://www.wikidata.org/wiki/Q3115850
#       Algar-Flynn-Oyamada reaction    https://www.wikidata.org/wiki/Q903717
#       Paternò–Büchi reaction    https://www.wikidata.org/wiki/Q902254
#       Prilezhaev epoxidation
#       oxa-Pictet-Spengler reaction
#     indole synthesis
#       Mori-Ban indole synthesis
#       Sandmeyer isonitrosoacetanilide isatin synthesis
#       Sandmeyer diphenylurea isatin synthesis
#       Larock indole synthesis
#       Bischler-Möhlau indole synthesis
#       Smith indole synthesis
#       Madelung indole synthesis    https://www.wikidata.org/wiki/Q2632831
#       Cadogan indole synthesis
#       Bartoli indole synthesis    https://www.wikidata.org/wiki/Q3508929
#       Fischer indole synthesis    https://www.wikidata.org/wiki/Q901218
#       Baeyer–Emmerling indole synthesis    https://www.wikidata.org/wiki/Q3159940
#     quinoline synthesis
#       Doebner reaction    https://www.wikidata.org/wiki/Q3772250
#       Niementowski quinoline synthesis    https://www.wikidata.org/wiki/Q2733837
#       Friedlander quinoline synthesis    https://www.wikidata.org/wiki/Q1058388
#       Knorr quinoline synthesis
#       Camps quinoline synthesis
#       Skraup reaction    https://www.wikidata.org/wiki/Q903836
#       Combes quinoline synthesis    https://www.wikidata.org/wiki/Q1058068
#     condensation reaction
#       ester condensation reaction
#       dealcoholative condensation
#         deethanolative condensation
#           Claisen condensation    https://www.wikidata.org/wiki/Q898501
#           Dieckmann cyclisation    https://www.wikidata.org/wiki/Q900932
#         Conrad-Limpach cyclisation    https://www.wikidata.org/wiki/Q1944895
#       molecular dehydration reaction
#         Ugi reaction    https://www.wikidata.org/wiki/Q2002373
#         Claisen-Schmidt condensation    https://www.wikidata.org/wiki/Q56298266
#         Wenker synthesis    https://www.wikidata.org/wiki/Q900233
#         Knorr pyrazole synthesis
#         Madelung indole synthesis    https://www.wikidata.org/wiki/Q2632831
#         Biginelli reaction
#         aldol condensation    https://www.wikidata.org/wiki/Q1027170
#           Perkin reaction    https://www.wikidata.org/wiki/Q898605
#           Mukaiyama aldol condensation    https://www.wikidata.org/wiki/Q1059787
#         Skraup reaction    https://www.wikidata.org/wiki/Q903836
#         Combes quinoline synthesis    https://www.wikidata.org/wiki/Q1058068
#       decarboxylative condensation
#         Knoevenagel condensation    https://www.wikidata.org/wiki/Q898972
#         Darzens reaction    https://www.wikidata.org/wiki/Q899351
#           haloethanoate ester-ketone Darzens reaction
#           haloethanoate ester-aldehyde Darzens reaction
#       Pictet-Spengler reaction    https://www.wikidata.org/wiki/Q899206
#       oxa-Pictet-Spengler reaction
#     elimination reaction
#     pyridine synthesis
#       Chichibabin pyridine synthesis
#       Kröhnke pyridine synthesis    https://www.wikidata.org/wiki/Q2144364
#       Hantzsch pyridine synthesis
#     carbazole synthesis
#       Borsche-Drechsel cyclisation
#       Cadogan carbazole synthesis
#     acridine synthesis
#       Bernthsen acridine synthesis
#     enolisation
#     accepting an electron pair in Lewis adduct formation
#     hydron donation
#     base catalysis
#       Brønsted base catalysis
#       Lewis base catalysis
#     Lewis adduct formation
#     electron pair donation in Lewis adduct formation
#     accepting a hydron
#     [3,3]-sigmatropic rearrangement
#       Johnson-Claisen rearrangement
#       Eschenmoser-Claisen rearrangement
#       Bellus-Claisen rearrangement
#       Ireland-Claisen rearrangement    https://www.wikidata.org/wiki/Q1945726
#       Claisen rearrangement    https://www.wikidata.org/wiki/Q900936
#       aza-Cope rearrangement
#         3-aza-Cope rearrangement
#         2-aza-Cope rearrangement
#         1-aza-Cope rearrangement
#       aromatic Claisen rearrangement
#       oxy-Cope rearrangement    https://www.wikidata.org/wiki/Q25326942
#       Cope rearrangement    https://www.wikidata.org/wiki/Q905087
# chemical entity
#   atom
#     metal atom
#       transition element atom
#         nickel atom
#         zinc atom
#         copper atom
#         titanium atom
#         palladium atom
#         platinum atom
#       sodium atom
#     phosphorus atom
#   group
#     amino groups
#       amino group
#     formyl group
#     nitro group
#     pseudohalo group
#     aryl group
#     carboxy group
#     hydroxy group
#   molecular entity
#     hydrogen chloride
#     hydrogen bromide
#     chalcones
#     alkene
#     phosphonium ylide
#     dibromine
#     nitrile
#     nitro compound
#     nitrate ester
#     carboximides
#       formamides
#     organooxygen compound
#       ether
#     enyne
#     tetrabromomethane
#     chromium coordination entity
#       chromium trioxide
#     tertiary phosphine
#     allenes
#     arylacetylene
#     phosphine oxide
#     cinnamic acids
#     sodium azide
# Bingel reaction    https://www.wikidata.org/wiki/Q1054818

# %%
# Out:
# []
# True
# t: -1
